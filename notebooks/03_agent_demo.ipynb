# %% [markdown]
# # Clinical Decision Agent — End-to-End Demo

# %%
import sys; sys.path.insert(0, '..')
from src.inference.predictor import ResistancePredictor
from src.agent.decision_agent import ClinicalDecisionAgent

patient = {
    'age': 68, 'sex': 'F', 'organism': 'E. coli',
    'creatinine': 1.4, 'wbc': 14.2, 'prior_antibiotics': 'Ampicillin'
}

resistance_scores = {
    'Ampicillin': 0.82, 'Ciprofloxacin': 0.45,
    'Meropenem': 0.12, 'Ceftriaxone': 0.61, 'Gentamicin': 0.33
}

agent = ClinicalDecisionAgent()
result = agent.recommend(patient, resistance_scores)
print(result)
